# %%
from pathlib import Path
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder
from sklearn.ensemble import IsolationForest
import plotly.express as px
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Edric-Matwiejew/notebook_share_test/main/Dataanalysis_workshop.csv')

# %%
df
# Out:
#    State  Year of Birth (YYYY) Country of Birth  highest academic degree  \
# 0    VIC                  1997          Germany            Master Degree
# 1     WA                  1972              USA            Master Degree
# 2    NSW                  1995        Australia          Bachelor Degree
# 3     WA                  1999           Israel      High School Diploma
# 4     WA                  2000        Australia      High School Diploma
# 5     WA                  1990        Australia            Master Degree
# 6     WA                  2001          Germany      High School Diploma
# 7     WA                  1998        Australia  Bachelor Honours Degree
# 8     WA                  1992        Australia      High School Diploma
# 9     WA                  1994        Australia          Bachelor Degree
# 10    WA                  1999            India          Bachelor Degree
#
#    Identity as aboriginal/torres strait islander Citizen/PR First Language  \
# 0                                             No         No         german
# 1                                             No        Yes        english
# 2                                             No        Yes        english
# 3                                             No        Yes         hebrew
# 4                                             No        Yes        english
# 5                                             No        Yes        english
# 6                                             No        Yes         german
# 7                                             No        Yes        english
# 8                                             No        Yes        english
# 9                                             No        Yes        english
# 10                                            No        Yes        english
#
#    gender
# 0   woman
# 1   woman
# 2   woman
# 3     man
# 4     man
# 5     man
# 6     man
# 7     man
# 8     man
# 9     man
# 10    man

# %%
le = OrdinalEncoder()
df_transformed = le.fit_transform(df)

# %%
le = LabelEncoder()
df_transformed = df.copy()
for col in df_transformed.select_dtypes(include='O').columns:
    df_transformed[col]=le.fit_transform(df_transformed[col])

# %%
df_transformed
# Out:
#     State  Year of Birth (YYYY)  Country of Birth  highest academic degree  \
# 0       1                  1997                 1                        3
# 1       2                  1972                 4                        3
# 2       0                  1995                 0                        0
# 3       2                  1999                 3                        2
# 4       2                  2000                 0                        2
# 5       2                  1990                 0                        3
# 6       2                  2001                 1                        2
# 7       2                  1998                 0                        1
# 8       2                  1992                 0                        2
# 9       2                  1994                 0                        0
# 10      2                  1999                 2                        0
#
#     Identity as aboriginal/torres strait islander  Citizen/PR  First Language  \
# 0                                               0           0               1
# 1                                               0           1               0
# 2                                               0           1               0
# 3                                               0           1               2
# 4                                               0           1               0
# 5                                               0           1               0
# 6                                               0           1               1
# 7                                               0           1               0
# 8                                               0           1               0
# 9                                               0           1               0
# 10                                              0           1               0
#
#     gender
# 0        1
# 1        1
# 2        1
# 3        0
# 4        0
# 5        0
# 6        0
# 7        0
# 8        0
# 9        0
# 10       0

# %%
clf = IsolationForest(random_state=0).fit_predict(df_transformed)

# %%
df['anomaly'] = clf

# %%
df
# Out:
#    State  Year of Birth (YYYY) Country of Birth  highest academic degree  \
# 0    VIC                  1997          Germany            Master Degree
# 1     WA                  1972              USA            Master Degree
# 2    NSW                  1995        Australia          Bachelor Degree
# 3     WA                  1999           Israel      High School Diploma
# 4     WA                  2000        Australia      High School Diploma
# 5     WA                  1990        Australia            Master Degree
# 6     WA                  2001          Germany      High School Diploma
# 7     WA                  1998        Australia  Bachelor Honours Degree
# 8     WA                  1992        Australia      High School Diploma
# 9     WA                  1994        Australia          Bachelor Degree
# 10    WA                  1999            India          Bachelor Degree
#
#    Identity as aboriginal/torres strait islander Citizen/PR First Language  \
# 0                                             No         No         german
# 1                                             No        Yes        english
# 2                                             No        Yes        english
# 3                                             No        Yes         hebrew
# 4                                             No        Yes        english
# 5                                             No        Yes        english
# 6                                             No        Yes         german
# 7                                             No        Yes        english
# 8                                             No        Yes        english
# 9                                             No        Yes        english
# 10                                            No        Yes        english
#
#    gender  anomaly
# 0   woman       -1
# 1   woman       -1
# 2   woman       -1
# 3     man       -1
# 4     man        1
# 5     man        1
# 6     man        1
# 7     man        1
# 8     man        1
# 9     man        1
# 10    man        1

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_transformed)
df['pca-one'] = pca_result[:,0]
df['pca-two'] = pca_result[:,1]
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.94619359 0.02710328]

# %%
df
# Out:
#    State  Year of Birth (YYYY) Country of Birth  highest academic degree  \
# 0    VIC                  1997          Germany            Master Degree
# 1     WA                  1972              USA            Master Degree
# 2    NSW                  1995        Australia          Bachelor Degree
# 3     WA                  1999           Israel      High School Diploma
# 4     WA                  2000        Australia      High School Diploma
# 5     WA                  1990        Australia            Master Degree
# 6     WA                  2001          Germany      High School Diploma
# 7     WA                  1998        Australia  Bachelor Honours Degree
# 8     WA                  1992        Australia      High School Diploma
# 9     WA                  1994        Australia          Bachelor Degree
# 10    WA                  1999            India          Bachelor Degree
#
#    Identity as aboriginal/torres strait islander Citizen/PR First Language  \
# 0                                             No         No         german
# 1                                             No        Yes        english
# 2                                             No        Yes        english
# 3                                             No        Yes         hebrew
# 4                                             No        Yes        english
# 5                                             No        Yes        english
# 6                                             No        Yes         german
# 7                                             No        Yes        english
# 8                                             No        Yes        english
# 9                                             No        Yes        english
# 10                                            No        Yes        english
#
#    gender  anomaly    pca-one   pca-two
# 0   woman       -1  -2.636756  1.043027
# 1   woman       -1  22.503981  0.995508
# 2   woman       -1  -0.883656 -1.823954
# 3     man       -1  -4.556084  2.807837
# 4     man        1  -5.752171 -0.262492
# 5     man        1   4.244009 -0.655778
# 6     man        1  -6.687722  1.004995
# 7     man        1  -3.822396 -0.871759
# 8     man        1   2.198466 -0.930861
# 9     man        1   0.095038 -1.648120
# 10    man        1  -4.702708  0.341599

# %%
df["anomaly"] = df["anomaly"].astype(str)
fig = px.scatter(df, x="pca-one", y="pca-two", color="anomaly",
                 hover_data=['State', 'Country of Birth', 'highest academic degree', 'Identity as aboriginal/torres strait islander', 'Citizen/PR'],
                 color_discrete_sequence=["indianred", "mediumblue"])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b9249a7f-549c-470e-b8e3-8aee77fcf2b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9249a7f-549c-470e-b8e3-8aee77fcf2b5")) {                    Plotly.newPlot(                        "b9249a7f-549c-470e-b8e3-8aee77fcf2b5",                        [{"customdata":[["VIC","Germany","Master Degree","No","No"],["WA","USA","Master Degree","No","Yes"],["NSW","Australia","Bachelor Degree","No","Yes"],["WA","Israel","High School Diploma","No","Yes"]],"hovertemplate":"anomaly=-1<br>pca-one=%{x}<br>pca-two=%{y}<br>State=%{customdata[0]}<br>Country of Birth=%{customdata[1]}<br>highest academic degree=%{customdata[2]}<br>Identity as aboriginal/torres strait islander=%{customdata[3]}<br>Citizen/PR=%{customdata[4]}<extra></extra>","legendgroup":"-1","marker":{"color":"indianred","symbol":"circle"},"mode":"markers","name":"-1","orientation":"v","showlegend":true,"x":[-2.6367562702418916,22.503980671259676,-0.8836562440746362,-4.556084397052469],"xaxis":"x","y":[1.0430266176119338,0.9955078550630563,-1.8239544184050709,2.8078365127310243],"yaxis":"y","type":"scatter"},{"customdata":[["WA","Australia","High School Diploma","No","Yes"],["WA","Australia","Master Degree","No","Yes"],["WA","Germany","High School Diploma","No","Yes"],["WA","Australia","Bachelor Honours Degree","No","Yes"],["WA","Australia","High School Diploma","No","Yes"],["WA","Australia","Bachelor Degree","No","Yes"],["WA","India","Bachelor Degree","No","Yes"]],"hovertemplate":"anomaly=1<br>pca-one=%{x}<br>pca-two=%{y}<br>State=%{customdata[0]}<br>Country of Birth=%{customdata[1]}<br>highest academic degree=%{customdata[2]}<br>Identity as aboriginal/torres strait islander=%{customdata[3]}<br>Citizen/PR=%{customdata[4]}<extra></extra>","legendgroup":"1","marker":{"color":"mediumblue","symbol":"circle"},"mode":"markers","name":"1","orientation":"v","showlegend":true,"x":[-5.752170838385962,4.244009074186045,-6.687722360397065,-3.822395804650054,2.1984657924859814,0.09503838680383943,-4.702708009933688],"xaxis":"x","y":[-0.2624915629654347,-0.6557782385432479,1.004994839917939,-0.8717594981345592,-0.9308613034633931,-1.6481198684281733,0.3415990646159429],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921 ...
